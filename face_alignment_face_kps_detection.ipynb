# %%
import face_alignment
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# %%
fa = face_alignment.FaceAlignment(face_alignment.LandmarksType.TWO_D, flip_input=False, device="cpu")

# %%
img = cv2.imread("Sandip.jpg")
preds = fa.get_landmarks(img)[0]
print(preds.shape)
# Out:
# (68, 2)

# %%
fig, ax = plt.subplots(figsize=(5, 5))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
ax.scatter(preds[:, 0], preds[:, 1], marker="+", c="g")
plt.show()

# %%
fa = face_alignment.FaceAlignment(face_alignment.LandmarksType.THREE_D, flip_input=False, device="cpu")
img = cv2.imread("Sandip.jpg")
preds = fa.get_landmarks(img)[0]
df = pd.DataFrame(preds)
df.columns = ["x", "y", "z"]
fig = px.scatter_3d(df, x="x", y="y", z="z")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       5 df.columns = ["x", "y", "z"]
#       6 fig = px.scatter_3d(df, x="x", y="y", z="z")
# ----> 7 fig.show()
#
# File c:\Users\SANDIP\Desktop\Vscode_projects\Computer_vision\.venv\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File c:\Users\SANDIP\Desktop\Vscode_projects\Computer_vision\.venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
